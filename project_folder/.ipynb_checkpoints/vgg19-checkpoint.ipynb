# %%
# 1. 创建 Keras 官方存放模型的隐藏文件夹
# !mkdir -p /home/ma-user/.keras/models/

# 2. 将当前目录下的文件移动/复制过去
# !cp vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5 /home/ma-user/.keras/models/

# 3. 检查是否移动成功
# !ls /home/ma-user/.keras/models/
